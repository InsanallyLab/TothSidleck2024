# %%
import sys, os
import json, pickle
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import time as pytime
import statsmodels.tsa.stattools as tsa
import ruptures as rpt
sys.path.append('../..')
import InsanallyLabEphysTools as ilep
from scipy.stats import gaussian_kde, sem, ttest_ind, ttest_rel, norm, mannwhitneyu, linregress, wilcoxon
from tqdm import tqdm
from types import SimpleNamespace
from sklearn import linear_model
from sklearn.model_selection import KFold
import seaborn as sns
import traceback
from itertools import product

plt.rcParams['legend.fontsize'] = 'small'
plt.rcParams['axes.labelsize'] = 'medium'
plt.rcParams['axes.formatter.limits'] = [-2,3]
plt.rcParams['axes.formatter.use_mathtext'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['figure.dpi'] = '150'

#Set global font parameters
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
#Set font type to TrueType for compatibility
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

TARGET_COLOR = '#ff3654'
NONTARGET_COLOR = '#5776ff'

CR_COLOR = '#808080'
NCR_COLOR = '#FF767C'
CNO_COLOR = '#00BFFF'
SWITCH_COLOR = '#B07A3B'
LASER_COLOR = '#3375E9'
GOOD_GREY = '#969696'
GOOD_GREEN = '#32A852'
NCR_COLOR_DESAT = '#D98C90'
CR_COLOR_DESAT = '#A0A0A0'
NCR_CR_cmap = mpl.colors.LinearSegmentedColormap.from_list('NCR-CR color map', [NCR_COLOR, CR_COLOR], N=1000)
PHASE_COLORS = ['#DEB9E0','#B78AB9','#906D92','#ABC5E8','#869BB7','#5E6C80']#,'#6ded94','#50d979','#36bf5f']

#dualanimalnames = ['BS_40','BS_41','BS_42','BS_49','BS_50','BS_51','BS_56','BS_59','BS_61','BS_67','BS_70','BS_72','BS_87','BS_108','DS_15','DS_19']
# dualanimalnames = ['BS_40','BS_41','BS_42','BS_49','BS_50','BS_51','BS_56','BS_59','BS_67','BS_70','BS_72','BS_87','BS_108','DS_15','DS_19']

animals = ['AE_287']

#act_directory = 'D:\\Analysis_Cache_archived_Oct_27_2022'
act_directory = 'D:\\Analysis_Cache'
ops_directory = 'D:\\Opsin_Cache'
beh_directory = 'P:\\Behavioor'
# Out:
# C:\Users\insan\anaconda3\envs\EphysPlotting\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
animalBehaviors = ilep.getAllBehavior(beh_directory)
# Out:
# Fetching files for BS_51
# Fetching files for BS_52
# Fetching files for BS_56
# Fetching files for BS_59
# Fetching files for BS_61
# Fetching files for BS_86
# Fetching files for BS_92
# Fetching files for BS_100
# Fetching files for BS_103
# Fetching files for BS_111
# Fetching files for BS_119
# Fetching files for BS_123
# Fetching files for BS_128
# Fetching files for BS_131
# Fetching files for BS_139
# Fetching files for BS_163
# Fetching files for BS_165
# Fetching files for BS_174
# Fetching files for BS_179
# Fetching files for BS_191
# Fetching files for BS_192
# Fetching files for BS_33
# Fetching files for BS_67
# Fetching files for BS_73
# Fetching files for BS_78
# Fetching files for BS_108
# Fetching files for BS_40
# Fetching files for BS_41
# Fetching files for BS_42
# Fetching files for BS_49
# Fetching files for BS_50
# Fetching files for BS_70
# Fetching files for BS_72
# Fetching files for BS_83
# Fetching files for BS_85
# Fetching files for BS_87
# Fetching files for BS_95
# Fetching files for BS_113
# Fetching files for DS_15
# Fetching files for DS_16
# Fetching files for DS_17
# C:\Users\insan\anaconda3\envs\EphysPlotting\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# Fetching files for DS_19
# Fetching files for DS_22
# Fetching files for DS_23
# Fetching files for DS_24
# Fetching files for DS_27
# Fetching files for DS_28
# Fetching files for DS_13
# Fetching files for BS_173
# Fetching files for BS_175
# Fetching files for BS_187
# Fetching files for BS_188
# Fetching files for BS_213
# Fetching files for BS_214
# Fetching files for TH_217
# Fetching files for AE_235
# Fetching files for AE_236
# Fetching files for TH_237
# Fetching files for AE_252
# Fetching files for AE_254
# Fetching files for AE_238
# Fetching files for AE_239
# Fetching files for AE_240
# Fetching files for AE_267
# Fetching files for AO_273
# Fetching files for AO_274
# Fetching files for AE_287
# P:\Behavioor\BS_61\behavior\BS_61_42v2_reversal.txt: No columns to parse from file
# P:\Behavioor\BS_103\behavior\BS_103_11v4_opto.txt: No columns to parse from file
# P:\Behavioor\BS_123\behavior\BS_123_18v1_opto.txt: No columns to parse from file
# ERROR: MULTIPLE REVERSALS IN ANIMAL BS_179
# P:\Behavioor\BS_191\behavior\BS_191_1v2.txt: No columns to parse from file
# P:\Behavioor\BS_33\behavior\BS_33_9v1.txt: No columns to parse from file
# P:\Behavioor\BS_33\behavior\BS_33_20v1_reversal.txt: No columns to parse from file
# P:\Behavioor\BS_49\behavior\BS_49_14v4_reversal.txt: No columns to parse from file
# P:\Behavioor\BS_87\behavior\BS_87_1v1.txt: No columns to parse from file
# DS_15 session 21 has no response time
# DS_15 session 22 has no response time
# DS_15 session 23 has no response time
# DS_15 session 24 has no response time
# DS_15 session 25 has no response time
# DS_15 session 26 has no response time
# DS_15 session 27 has no response time
# DS_15 session 29 has no response time
# DS_16 session 21 has no response time
# DS_16 session 22 has no response time
# DS_16 session 23 has no response time
# DS_16 session 24 has no response time
# DS_16 session 25 has no response time
# DS_16 session 26 has no response time
# DS_16 session 27 has no response time
# DS_16 session 28 has no response time
# DS_16 session 29 has no response time
# DS_16 session 30 has no response time
# DS_16 session 31 has no response time
# DS_17 session 13 has no response time
# DS_17 session 14 has no response time
# DS_17 session 15 has no response time
# DS_17 session 16 has no response time
# DS_17 session 17 has no response time
# DS_17 session 18 has no response time
# DS_17 session 19 has no response time
# DS_17 session 20 has no response time
# DS_17 session 21 has no response time
# DS_17 session 22 has no response time
# DS_17 session 23 has no response time
# DS_17 session 24 has no response time
# DS_17 session 25 has no response time
# DS_17 session 26 has no response time
# DS_17 session 27 has no response time
# DS_19 session 11 has no response time
# DS_19 session 12 has no response time
# DS_19 session 13 has no response time
# DS_19 session 14 has no response time
# DS_19 session 15 has no response time
# DS_19 session 16 has no response time
# DS_19 session 17 has no response time
# DS_19 session 18 has no response time
# DS_19 session 19 has no response time
# DS_19 session 20 has no response time
# DS_19 session 21 has no response time
# DS_19 session 22 has no response time
# DS_19 session 23 has no response time
# DS_19 session 24 has no response time
# DS_19 session 25 has no response time
# DS_19 session 26 has no response time
# DS_19 session 27 has no response time
# DS_22 session 13 has no response time
# DS_22 session 14 has no response time
# DS_22 session 15 has no response time
# DS_22 session 16 has no response time
# DS_22 session 17 has no response time
# DS_23 session 15 has no response time
# DS_23 session 16 has no response time
# DS_23 session 17 has no response time
# DS_23 session 18 has no response time
# DS_23 session 19 has no response time
# DS_23 session 20 has no response time
# DS_23 session 21 has no response time
# DS_23 session 22 has no response time
# DS_23 session 23 has no response time
# DS_23 session 24 has no response time
# DS_23 session 25 has no response time
# DS_23 session 26 has no response time
# DS_23 session 27 has no response time
# DS_23 session 28 has no response time
# DS_23 session 32 has no response time
# DS_23 session 33 has no response time
# DS_24 session 11 has no response time
# DS_24 session 12 has no response time
# DS_24 session 13 has no response time
# DS_24 session 14 has no response time
# DS_24 session 15 has no response time
# DS_24 session 16 has no response time
# DS_24 session 17 has no response time
# DS_24 session 18 has no response time
# DS_24 session 19 has no response time
# DS_24 session 20 has no response time
# DS_24 session 21 has no response time
# DS_24 session 22 has no response time
# DS_24 session 23 has no response time
# DS_24 session 24 has no response time
# DS_24 session 25 has no response time
# DS_24 session 26 has no response time
# P:\Behavioor\BS_173\behavior\BS_173_9v2.txt: No columns to parse from file
# P:\Behavioor\AE_238\behavior\AE_238_48v2.txt: No columns to parse from file
# P:\Behavioor\AE_239\behavior\AE_239_27v3.txt: No columns to parse from file
# P:\Behavioor\AO_273\behavior\AO_273_20v2_reversal.txt: No columns to parse from file

# %%
learning_phases,_,_ = ilep.calculateLearningPhasesV2(animals,animalBehaviors,plot=True)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
EnumSession = []
EnumClust = []
sessions = os.listdir(ops_directory)
for session in tqdm(sessions):
    sessionfile = ilep.loadSessionCached(ops_directory,session)
    
    if sessionfile.meta.task == 'passive no behavior':
        continue
    if sessionfile.meta.task in ['tuning nonreversal','tuning switch','tuning reversal']:
        continue
    if sessionfile.meta.region != 'AC':
        continue
    
    if sessionfile.meta.animal not in animals:
        continue
    
    for clust in sessionfile.clusters.good:
        EnumSession.append(session)
        EnumClust.append(clust)
# Out:
# 100%|██████████| 147/147 [00:02<00:00, 52.33it/s]

# %%
EILphases = np.full_like(EnumSession,np.nan)
error_animals = []

for idx,session in enumerate(tqdm(EnumSession)):
    sessionfile = ilep.loadSessionCached(ops_directory,session)
    
    try:
        animal = sessionfile.meta.animal
        day = sessionfile.meta.day_of_training
        
        if sessionfile.meta.task in ['switch','opto switch','opto control switch','tuning switch']:
            EILphases[idx] = 'switch'

        elif sessionfile.meta.task in ['nonreversal','opto nonreversal','opto control nonreversal','tuning nonreversal'] and day in learning_phases[animal].pre_early_days:
            EILphases[idx] = 'pre early'
        elif sessionfile.meta.task in ['nonreversal','opto nonreversal','opto control nonreversal','tuning nonreversal']  and day in learning_phases[animal].pre_late_days:
            EILphases[idx] = 'pre late'
        elif sessionfile.meta.task in ['nonreversal','opto nonreversal','opto control nonreversal','tuning nonreversal'] and day in learning_phases[animal].pre_expert_days:
            EILphases[idx] = 'pre expert'

        elif sessionfile.meta.task in ['reversal','opto reversal','opto control reversal','tuning reversal']  and day in learning_phases[animal].post_early_days:
            EILphases[idx] = 'post early'
        elif sessionfile.meta.task in ['reversal','opto reversal','opto control reversal','tuning reversal']  and day in learning_phases[animal].post_late_days:
            EILphases[idx] = 'post late'
        elif sessionfile.meta.task in ['reversal','opto reversal','opto control reversal','tuning reversal']  and day in learning_phases[animal].post_expert_days:
            EILphases[idx] = 'post expert'
    except Exception as e:
        #print(ilep.generateDateString(sessionfile))
        error_animals.append(sessionfile.meta.animal)
        pass
        raise e
                             
error_animals = np.unique(error_animals)
print('errors for: '+str(error_animals))
# Out:
#   0%|          | 0/288 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e3c39ac9c9d1> in <module>
#      29         error_animals.append(sessionfile.meta.animal)
#      30         pass
# ---> 31         raise e
#      32
#      33 error_animals = np.unique(error_animals)
#
# <ipython-input-3-e3c39ac9c9d1> in <module>
#      19             EILphases[idx] = 'pre expert'
#      20
# ---> 21         elif sessionfile.meta.task in ['reversal','opto reversal','opto control reversal','tuning reversal']  and day in learning_phases[animal].post_early_days:
#      22             EILphases[idx] = 'post early'
#      23         elif sessionfile.meta.task in ['reversal','opto reversal','opto control reversal','tuning reversal']  and day in learning_phases[animal].post_late_days:
#
# NameError: name 'learning_phases' is not defined

# %%
def get_response_times_with_default(sessionfile):
    response_times_in_trial = (sessionfile.trials.response-sessionfile.trials.starts)
    default_response_time = np.nanmedian(response_times_in_trial)

    response_times = sessionfile.trials.response
    nogo_trials = np.isnan(response_times)
    response_times[nogo_trials] = sessionfile.trials.starts[nogo_trials]+default_response_time
    return response_times

# %%
### Reset raster directory

os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters','pngs'))
os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters','pdfs'))
for modcat in ['CR','NCR','Middle']:
    os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters',modcat))
    os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters',modcat,'pdfs'))
    os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters',modcat,'pngs'))
    for phase in ['pre early','pre late','pre expert','switch','post early','post late','post expert']:
        os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters',modcat,phase))
        os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters',modcat,phase,'pdfs'))
        os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters',modcat,phase,'pngs'))
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-8-0f475776c2c8> in <module>
#       1 ### Reset raster directory
#       2
# ----> 3 os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters','pngs'))
#       4 os.mkdir(os.path.join('D:\\\\TempFigures','OpsinControlRasters','pdfs'))
#       5 for modcat in ['CR','NCR','Middle']:
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'D:\\\\TempFigures\\OpsinControlRasters\\pngs'

# %%
def visualizeClusterChoiceInternal(sessionfile,clust,ax1,ax2):
    bw_scott_factor = 3

    response_times = get_response_times_with_default(sessionfile)
    
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax1.get_yaxis().set_visible(False)

    #FRmod = sessionfile.responsiveness[clust]['all_trials'].FRmodulation
    FRmod_CR_NCR_threshold = 3.5
    Ramping_CR_NCR_threshold = 5.72
    
#     FRmod_color = NCR_CR_cmap( (FRmod-1)/5)
#     FRmod_color = NCR_CR_cmap( (FRmod-1)/5)
    mn = 3.5
    spread = 2
    Y = sessionfile.responsiveness[clust]['all_trials'].FRmodulation
    if np.isnan(Y):
        color_to_use = 'k'
    else:
        color_to_use = NCR_CR_cmap( (Y-(mn-spread/2))/ (spread) )

    #Sort trials by response time
    allConditions = ilep.getAllConditions(sessionfile,clust,trialsPerDayLoaded='NO_TRIM')
    trialsToPlot = allConditions['all_trials'].trials
    ### If reordering trials, do it here
    
#     # Nogo then go
#     trialsToPlot = np.concatenate((allConditions['nogo'].trials,allConditions['go'].trials))
    
    
    # Laser then non-laser
    trialsToPlot = np.concatenate((allConditions['laser_off'].trials,allConditions['laser_on'].trials))
    
#     # Just nogo
#     trialsToPlot = allConditions['nogo'].trials
    
    ### End trial reordering
    trialsToPlotGo = allConditions['go'].trials

    response_times_trimmed = response_times[trialsToPlot] - sessionfile.trials.starts[trialsToPlot]
    response_times_trimmed = response_times_trimmed * 1000 / sessionfile.meta.fs
    
    new_go_trials_idx_list = np.where(np.isin(trialsToPlot,trialsToPlotGo))[0]

    clustSpikes = ilep.getSpikeTimes(sessionfile,clust=clust)
    trialSpikes = []
    for trial in trialsToPlot:

        #Need to get spike times for each trial...
        starttime = sessionfile.trials.starts[trial] - 0.5*sessionfile.meta.fs
        endtime = sessionfile.trials.starts[trial] + 1.0*sessionfile.meta.fs
#         starttime = response_times[trial]-2.75*sessionfile.meta.fs
#         endtime = response_times[trial]+0.75*sessionfile.meta.fs
        
        this_trial_spikes = ilep.getSpikeTimes(sessionfile,clust=clust,starttime=starttime,endtime=endtime)
        this_trial_spikes = this_trial_spikes - sessionfile.trials.starts[trial]#response_times[trial]
        this_trial_spikes = this_trial_spikes * 1000 / sessionfile.meta.fs

        trialSpikes.append(this_trial_spikes)
    trialSpikes = np.array(trialSpikes,dtype='object')

    #Plot Raster
    for idx,trial in enumerate(trialsToPlot):
        ax1.scatter(trialSpikes[idx],np.ones_like(trialSpikes[idx])*idx,color=color_to_use,s=1.5,marker='o',lw=0)

        trialend = response_times[trial]
        trialstart = sessionfile.trials.starts[trial]
        trial_duration = trialend-trialstart
        trial_duration = trial_duration * 1000 / 30000

        
    ###################################################
    
#     ### Plot stimulus times
#     stimulus_times = -response_times_trimmed
#     ax1.scatter(stimulus_times,range(len(trialsToPlot)),marker='o',fc='k',ec='k',zorder=-1,s=1.5,label='stimulus')
    
#     ### Plot response times
#     go_trials = new_go_trials_idx_list
#     ax1.scatter(np.zeros_like(go_trials),go_trials,marker='o',fc='g',ec='g',zorder=-1,s=1.5,label='response')
    
    ###################################################
    
    ax1.axhline(len(allConditions['laser_off'].trials))
    
    #ax1.fill_betweenx(range(len(trialsToPlot)),-response_times_trimmed_sorted,100-response_times_trimmed_sorted,alpha=0.125,color='k',lw=0,label='stimulus')
    
    #ax1.axvline(0,lw=2.5,color='green',label='Response')
    lgd = ax1.legend(frameon=False,loc=(0.6,1))

    #if EIL == 'switch':
    #    try:
    #        switch_point = np.where(np.greater(trialsToPlot,200))[0][0]-0.5
    #        ax1.axhline(switch_point,linestyle='--',lw=1,zorder=-10,color='k')
    #    except:
    #        pass

    #Plot PSTH
    starttime = -50
    endtime = 150
    PSTHstart = starttime - 500
    PSTHend = endtime + 500
    xrange = np.linspace(starttime,endtime,num=1000)
    numSplits = min(10,len(trialSpikes))
    if numSplits < 2:
        return False,[] ### Return a failure
    FR = np.full((numSplits,len(xrange)),np.nan)
    kf = KFold(n_splits=numSplits)
    for idx,(train_index,_) in enumerate(kf.split(trialSpikes)):
        PSTHspikes = np.concatenate(trialSpikes[train_index])
        if len(PSTHspikes) == 0:
            FR[idx,:] = np.zeros(len(xrange))
            continue
        bw = len(PSTHspikes)**(-1./5) / bw_scott_factor
        KDE = gaussian_kde(PSTHspikes,bw_method=bw)
        FR[idx,:] = KDE.evaluate(xrange)
        FR[idx,:] = FR[idx,:] * len(PSTHspikes) / len(train_index) * 1000 #1000 is conversion to s/s because units are all in ms for this plot
    avg_FR = np.mean(FR,axis=0)
    sem_FR = np.std(FR,axis=0)

    ax2.plot(xrange,avg_FR,lw=1,color=color_to_use)
    ax2.fill_between(xrange,avg_FR-sem_FR,avg_FR+sem_FR,color=color_to_use,alpha=0.5,zorder=-10,lw=0)

    max_FR_value = np.max(avg_FR+sem_FR) * 1.1
    sequence_of_possible_axis_limits = np.array([1,2,4,6,8,10,12,16,20,30,40,50,60,80,100,120,140,150,160,180,200])
    idx_of_okay_limits = np.greater_equal(sequence_of_possible_axis_limits,max_FR_value)
    valid_limits = sequence_of_possible_axis_limits[idx_of_okay_limits]
    limit = np.min(valid_limits)
    ax2.set_ylim([0,limit])
    ax2.set_yticks([0,limit/2,limit])
    ax2.set_yticklabels(['0',str(int(limit/2)),str(limit)])
    ylab = ax2.set_ylabel('Firing rate (spikes/s)')

    #ax2.plot([0,100],[limit,limit],color='k',lw=3,linestyle='-',zorder=10)

    ax2.set_xlim([starttime,endtime])
    #ax2.set_xticks([0,500,1000,1500])
    #ax2.set_xticklabels(['0','0.5','1','1.5'])
#     #ax2.set_xticks([-0,-500,-1000,-1500,-2000,-2500])
#     ax2.set_xticks([-500,-250,0,250,500])
#     ax2.set_xticklabels(['-0.5','-0.25','0','0.25','0.5'])
#     ax2.set_xlim([-50,150])
#     ax2.set_xticks([-50,-25,0,25,50,75,100,125,150])
#     ax2.set_xticklabels(['-50','-25','0','25','50','75','100','125','150'])
    xlab = ax2.set_xlabel('Time relative to response (ms)')
    
    ax1.axvline(0,c='k',lw=0.5)
    ax1.axvline(10,c='r',lw=0.5)
    ax1.axvline(20,c='g',lw=0.5)
    
    ################################################################
    
#     ax1.fill_between([-50,50],[ax1.get_ylim()[0]]*2,[ax1.get_ylim()[1]]*2,color='g',lw=0,alpha=0.2)
    
    artists = [lgd,ylab,xlab]
    
    return True,artists

# %%
for idx,(session,clust) in tqdm(enumerate(zip(EnumSession,EnumClust))):
    plt.close('all')
    sessionfile = ilep.loadSessionCached(ops_directory,session)
    
    fig = plt.figure(figsize=(3,6))
    gs = fig.add_gridspec(2,1,height_ratios=[2,1],hspace=0.0125)#,wspace=0.5)#0.1)
#     ax1 = plt.subplot(gs[0,0])#Raster
#     ax2 = plt.subplot(gs[1,0],sharex=ax1)#PSTH
    
    ax3 = plt.subplot(gs[0,0])#Raster
    ax4 = plt.subplot(gs[1,0],sharex=ax3)#PSTH
    
    #visualizeClusterInternal(sessionfile,clust,ax1,ax2)
    success,artists = visualizeClusterChoiceInternal(sessionfile,clust,ax3,ax4)
    if not success:
        continue
    
#     ax3.set_title(f"{session} clust {clust}\nFRmodc_go={np.around(sessionfile.responsiveness[clust]['go'].FRmodulation_choice,2)}, FRmodc_nogo={np.around(sessionfile.responsiveness[clust]['nogo'].FRmodulation_choice,2)}",fontsize=8)
    
    #Determine FRmod category
    FRmodCategory = 'ERROR'
    FRmod = sessionfile.responsiveness[clust]['all_trials'].FRmodulation
    if FRmod < 1:
        FRmodCategory = 'NCR'
    elif FRmod > 8:
        FRmodCategory = 'CR'
    else:
        FRmodCategory = 'Middle'
    #Skip unidentified category neurons
    if FRmodCategory in ['ERROR','nan',np.nan]:
        continue

    region = sessionfile.meta.region

    EIL = EILphases[idx]
    #Skip unidentified phase neurons
    if EIL in ['ERROR','nan',np.nan]:
        continue
        
#     break
        
    try:
        if not FRmodCategory == 'ERROR':
            fig.savefig(os.path.join('D:\\\\TempFigures','OpsinControlRasters',FRmodCategory,EIL,'pdfs',ilep.generateDateString(sessionfile)+' '+str(clust)+'.pdf'),transparent=False,facecolor="white",dpi=400, bbox_extra_artists=(artists), bbox_inches='tight')
            fig.savefig(os.path.join('D:\\\\TempFigures','OpsinControlRasters',FRmodCategory,EIL,'pngs',ilep.generateDateString(sessionfile)+' '+str(clust)+'.png'),transparent=False,facecolor="white",dpi=400, bbox_extra_artists=(artists), bbox_inches='tight')
            fig.savefig(os.path.join('D:\\\\TempFigures','OpsinControlRasters',FRmodCategory,'pdfs',ilep.generateDateString(sessionfile)+' '+str(clust)+'.pdf'),transparent=False,facecolor="white",dpi=400, bbox_extra_artists=(artists), bbox_inches='tight')
            fig.savefig(os.path.join('D:\\\\TempFigures','OpsinControlRasters',FRmodCategory,'pngs',ilep.generateDateString(sessionfile)+' '+str(clust)+'.png'),transparent=False,facecolor="white",dpi=400, bbox_extra_artists=(artists), bbox_inches='tight')
        fig.savefig(os.path.join('D:\\\\TempFigures','OpsinControlRasters','pdfs',ilep.generateDateString(sessionfile)+' '+str(clust)+'.pdf'),transparent=False,facecolor="white",dpi=400, bbox_extra_artists=(artists), bbox_inches='tight')
        fig.savefig(os.path.join('D:\\\\TempFigures','OpsinControlRasters','pngs',ilep.generateDateString(sessionfile)+' '+str(clust)+'.png'),transparent=False,facecolor="white",dpi=400, bbox_extra_artists=(artists), bbox_inches='tight')
    except Exception as e:
        print(e)
# Out:
# 0it [00:00, ?it/s]No handles with labels found to put in legend.
# 1it [00:11, 11.40s/it]No handles with labels found to put in legend.
# 2it [00:22, 11.25s/it]No handles with labels found to put in legend.
# 3it [00:34, 11.44s/it]No handles with labels found to put in legend.
# 4it [00:45, 11.31s/it]No handles with labels found to put in legend.
# 5it [00:53, 10.06s/it]No handles with labels found to put in legend.
# 6it [01:02,  9.95s/it]No handles with labels found to put in legend.
# 7it [01:14, 10.60s/it]No handles with labels found to put in legend.
# 8it [01:26, 10.91s/it]No handles with labels found to put in legend.
# 9it [01:31,  9.17s/it]No handles with labels found to put in legend.
# 10it [01:42,  9.71s/it]No handles with labels found to put in legend.
# 11it [01:53, 10.08s/it]No handles with labels found to put in legend.
# 12it [02:03, 10.09s/it]No handles with labels found to put in legend.
# 13it [02:15, 10.59s/it]No handles with labels found to put in legend.
# 14it [02:25, 10.39s/it]No handles with labels found to put in legend.
# 15it [02:35, 10.45s/it]No handles with labels found to put in legend.
# 16it [02:45, 10.08s/it]No handles with labels found to put in legend.
# 17it [02:57, 10.90s/it]No handles with labels found to put in legend.
# 18it [03:06, 10.21s/it]No handles with labels found to put in legend.
# 19it [03:15,  9.83s/it]No handles with labels found to put in legend.
# 20it [03:20,  8.38s/it]No handles with labels found to put in legend.
# 21it [03:29,  8.47s/it]No handles with labels found to put in legend.
# 22it [03:36,  8.26s/it]No handles with labels found to put in legend.
# 23it [03:45,  8.39s/it]No handles with labels found to put in legend.
# 24it [03:54,  8.45s/it]No handles with labels found to put in legend.
# 25it [03:58,  7.26s/it]No handles with labels found to put in legend.
# 26it [04:05,  7.10s/it]No handles with labels found to put in legend.
# 27it [04:12,  6.99s/it]No handles with labels found to put in legend.
# 28it [04:21,  7.54s/it]No handles with labels found to put in legend.
# 29it [04:29,  7.92s/it]No handles with labels found to put in legend.
# 30it [04:38,  8.18s/it]No handles with labels found to put in legend.
# 31it [04:43,  7.12s/it]No handles with labels found to put in legend.
# 32it [04:51,  7.38s/it]No handles with labels found to put in legend.
# 33it [04:55,  6.44s/it]No handles with labels found to put in legend.
# 34it [05:04,  7.07s/it]No handles with labels found to put in legend.
# 35it [05:07,  6.03s/it]No handles with labels found to put in legend.
# 36it [05:16,  6.87s/it]No handles with labels found to put in legend.
# 37it [05:21,  6.18s/it]No handles with labels found to put in legend.
# 38it [05:25,  5.79s/it]No handles with labels found to put in legend.
# 39it [05:35,  6.81s/it]No handles with labels found to put in legend.
# 40it [05:43,  7.35s/it]No handles with labels found to put in legend.
# 41it [05:52,  7.68s/it]No handles with labels found to put in legend.
# 42it [05:58,  7.17s/it]No handles with labels found to put in legend.
# 43it [06:06,  7.56s/it]No handles with labels found to put in legend.
# 44it [06:15,  7.93s/it]No handles with labels found to put in legend.
# 45it [06:24,  8.30s/it]No handles with labels found to put in legend.
# 46it [06:34,  8.72s/it]No handles with labels found to put in legend.
# 47it [06:42,  8.58s/it]No handles with labels found to put in legend.
# 48it [06:50,  8.48s/it]No handles with labels found to put in legend.
# 49it [06:59,  8.55s/it]No handles with labels found to put in legend.
# 50it [07:04,  7.34s/it]No handles with labels found to put in legend.
# 51it [07:08,  6.54s/it]No handles with labels found to put in legend.
# 52it [07:13,  5.87s/it]No handles with labels found to put in legend.
# 53it [07:16,  5.27s/it]No handles with labels found to put in legend.
# 54it [07:28,  7.10s/it]No handles with labels found to put in legend.
# 55it [07:39,  8.46s/it]No handles with labels found to put in legend.
# 56it [07:50,  9.06s/it]No handles with labels found to put in legend.
# 57it [08:02,  9.96s/it]No handles with labels found to put in legend.
# 58it [08:15, 10.95s/it]No handles with labels found to put in legend.
# 59it [08:28, 11.54s/it]No handles with labels found to put in legend.
# 60it [08:33,  9.56s/it]No handles with labels found to put in legend.
# 61it [08:43,  9.64s/it]No handles with labels found to put in legend.
# 62it [08:54, 10.10s/it]No handles with labels found to put in legend.
# 63it [09:02,  9.58s/it]No handles with labels found to put in legend.
# 64it [09:07,  8.07s/it]No handles with labels found to put in legend.
# 65it [09:19,  9.29s/it]No handles with labels found to put in legend.
# 66it [09:29,  9.56s/it]No handles with labels found to put in legend.
# 67it [09:41, 10.30s/it]No handles with labels found to put in legend.
# 68it [09:50,  9.76s/it]No handles with labels found to put in legend.
# 69it [10:02, 10.49s/it]No handles with labels found to put in legend.
# 70it [10:16, 11.41s/it]No handles with labels found to put in legend.
# 71it [10:29, 11.94s/it]No handles with labels found to put in legend.
# 72it [10:40, 11.88s/it]No handles with labels found to put in legend.
# 73it [10:53, 12.11s/it]No handles with labels found to put in legend.
# 74it [11:05, 12.04s/it]No handles with labels found to put in legend.
# 75it [11:14, 11.26s/it]No handles with labels found to put in legend.
# 76it [11:21,  9.99s/it]No handles with labels found to put in legend.
# 77it [11:32, 10.07s/it]No handles with labels found to put in legend.
# 78it [11:42, 10.05s/it]No handles with labels found to put in legend.
# 79it [11:51,  9.91s/it]No handles with labels found to put in legend.
# 80it [12:04, 10.72s/it]No handles with labels found to put in legend.
# 81it [12:17, 11.58s/it]No handles with labels found to put in legend.
# 82it [12:31, 12.17s/it]No handles with labels found to put in legend.
# 83it [12:40, 11.06s/it]No handles with labels found to put in legend.
# 84it [12:46,  9.56s/it]No handles with labels found to put in legend.
# 85it [12:50,  8.11s/it]No handles with labels found to put in legend.
# 86it [12:59,  8.19s/it]No handles with labels found to put in legend.
# 87it [13:09,  8.87s/it]No handles with labels found to put in legend.
# 88it [13:17,  8.55s/it]No handles with labels found to put in legend.
# 89it [13:29,  9.56s/it]No handles with labels found to put in legend.
# 90it [13:39,  9.76s/it]No handles with labels found to put in legend.
# 91it [13:51, 10.34s/it]No handles with labels found to put in legend.
# 92it [13:59,  9.62s/it]No handles with labels found to put in legend.
# 93it [14:11, 10.53s/it]No handles with labels found to put in legend.
# 94it [14:24, 11.25s/it]No handles with labels found to put in legend.
# 95it [14:37, 11.81s/it]No handles with labels found to put in legend.
# 96it [14:43, 10.01s/it]No handles with labels found to put in legend.
# 97it [14:51,  9.33s/it]No handles with labels found to put in legend.
# 98it [15:00,  9.11s/it]No handles with labels found to put in legend.
# 99it [15:06,  8.28s/it]No handles with labels found to put in legend.
# 100it [15:18,  9.53s/it]No handles with labels found to put in legend.
# 101it [15:23,  8.21s/it]No handles with labels found to put in legend.
# 102it [15:31,  8.10s/it]No handles with labels found to put in legend.
# 103it [15:41,  8.59s/it]No handles with labels found to put in legend.
# 104it [15:51,  8.95s/it]No handles with labels found to put in legend.
# 105it [16:04, 10.36s/it]No handles with labels found to put in legend.
# 106it [16:15, 10.25s/it]No handles with labels found to put in legend.
# 107it [16:28, 11.27s/it]No handles with labels found to put in legend.
# 108it [16:41, 11.87s/it]No handles with labels found to put in legend.
# 109it [16:54, 12.11s/it]No handles with labels found to put in legend.
# 110it [17:09, 13.10s/it]No handles with labels found to put in legend.
# 111it [17:15, 10.79s/it]No handles with labels found to put in legend.
# 112it [17:23, 10.02s/it]No handles with labels found to put in legend.
# 113it [17:34, 10.30s/it]No handles with labels found to put in legend.
# 114it [17:45, 10.59s/it]No handles with labels found to put in legend.
# 115it [17:54, 10.06s/it]No handles with labels found to put in legend.
# 116it [18:07, 10.82s/it]No handles with labels found to put in legend.
# 117it [18:17, 10.65s/it]No handles with labels found to put in legend.
# 118it [18:30, 11.38s/it]No handles with labels found to put in legend.
# 119it [18:37, 10.01s/it]No handles with labels found to put in legend.
# 120it [18:48, 10.43s/it]No handles with labels found to put in legend.
# 121it [19:02, 11.45s/it]No handles with labels found to put in legend.
# 122it [19:16, 12.06s/it]No handles with labels found to put in legend.
# 123it [19:28, 12.13s/it]No handles with labels found to put in legend.
# 124it [19:39, 11.87s/it]No handles with labels found to put in legend.
# 125it [19:52, 12.28s/it]No handles with labels found to put in legend.
# 126it [20:06, 12.54s/it]No handles with labels found to put in legend.
# 127it [20:18, 12.62s/it]No handles with labels found to put in legend.
# 128it [20:27, 11.47s/it]No handles with labels found to put in legend.
# 129it [20:40, 11.84s/it]No handles with labels found to put in legend.
# 130it [20:53, 12.11s/it]No handles with labels found to put in legend.
# 131it [21:05, 12.30s/it]No handles with labels found to put in legend.
# 132it [21:12, 10.74s/it]No handles with labels found to put in legend.
# 133it [21:24, 11.12s/it]No handles with labels found to put in legend.
# 134it [21:36, 11.17s/it]No handles with labels found to put in legend.
# 135it [21:51, 12.39s/it]No handles with labels found to put in legend.
# 136it [22:05, 12.83s/it]No handles with labels found to put in legend.
# 137it [22:19, 13.13s/it]No handles with labels found to put in legend.
# 138it [22:33, 13.46s/it]No handles with labels found to put in legend.
# 139it [22:44, 12.72s/it]No handles with labels found to put in legend.
# 140it [22:54, 12.07s/it]No handles with labels found to put in legend.
# 141it [23:09, 12.80s/it]No handles with labels found to put in legend.
# 142it [23:23, 13.17s/it]No handles with labels found to put in legend.
# 143it [23:29, 10.95s/it]No handles with labels found to put in legend.
# 144it [23:36,  9.72s/it]No handles with labels found to put in legend.
# 145it [23:49, 10.89s/it]No handles with labels found to put in legend.
# 146it [24:05, 12.23s/it]No handles with labels found to put in legend.
# 147it [24:19, 13.02s/it]No handles with labels found to put in legend.
# 148it [24:34, 13.54s/it]No handles with labels found to put in legend.
# 149it [24:39, 11.04s/it]No handles with labels found to put in legend.
# 150it [24:49, 10.63s/it]No handles with labels found to put in legend.
# 151it [25:02, 11.30s/it]No handles with labels found to put in legend.
# 152it [25:14, 11.56s/it]No handles with labels found to put in legend.
# 153it [25:27, 12.04s/it]No handles with labels found to put in legend.
# 154it [25:38, 11.79s/it]No handles with labels found to put in legend.
# 155it [25:51, 12.06s/it]No handles with labels found to put in legend.
# 156it [26:05, 12.53s/it]No handles with labels found to put in legend.
# 157it [26:18, 12.61s/it]No handles with labels found to put in legend.
# 158it [26:32, 13.15s/it]No handles with labels found to put in legend.
# 159it [26:48, 13.94s/it]No handles with labels found to put in legend.
# 160it [27:04, 14.59s/it]No handles with labels found to put in legend.
# 161it [27:12, 12.62s/it]No handles with labels found to put in legend.
# 162it [27:19, 10.88s/it]No handles with labels found to put in legend.
# 163it [27:30, 10.89s/it]No handles with labels found to put in legend.
# 164it [27:43, 11.76s/it]No handles with labels found to put in legend.
# 165it [27:58, 12.74s/it]No handles with labels found to put in legend.
# 166it [28:04, 10.58s/it]No handles with labels found to put in legend.
# 167it [28:17, 11.37s/it]No handles with labels found to put in legend.
# 168it [28:23,  9.81s/it]No handles with labels found to put in legend.
# 169it [28:35, 10.46s/it]No handles with labels found to put in legend.
# 170it [28:45, 10.13s/it]No handles with labels found to put in legend.
# 171it [28:51,  9.10s/it]No handles with labels found to put in legend.
# 172it [29:06, 10.77s/it]No handles with labels found to put in legend.
# 173it [29:25, 13.35s/it]No handles with labels found to put in legend.
# 174it [29:48, 16.23s/it]No handles with labels found to put in legend.
# 175it [30:10, 17.70s/it]No handles with labels found to put in legend.
# 176it [30:30, 18.47s/it]No handles with labels found to put in legend.
# 177it [30:47, 18.23s/it]No handles with labels found to put in legend.
# 178it [31:03, 17.40s/it]No handles with labels found to put in legend.
# 179it [31:24, 18.45s/it]No handles with labels found to put in legend.
# 180it [31:42, 18.25s/it]No handles with labels found to put in legend.
# 181it [32:00, 18.17s/it]No handles with labels found to put in legend.
# 182it [32:18, 18.17s/it]No handles with labels found to put in legend.
# 183it [32:33, 17.21s/it]No handles with labels found to put in legend.
# 184it [32:45, 15.82s/it]No handles with labels found to put in legend.
# 185it [33:02, 15.97s/it]No handles with labels found to put in legend.
# 186it [33:22, 17.26s/it]No handles with labels found to put in legend.
# 187it [33:27, 13.70s/it]No handles with labels found to put in legend.
# 188it [33:48, 15.85s/it]No handles with labels found to put in legend.
# 189it [33:53, 12.67s/it]No handles with labels found to put in legend.
# 190it [34:08, 13.30s/it]No handles with labels found to put in legend.
# 191it [34:26, 14.75s/it]No handles with labels found to put in legend.
# 192it [34:46, 16.27s/it]No handles with labels found to put in legend.
# 193it [35:04, 16.88s/it]No handles with labels found to put in legend.
# 194it [35:24, 17.79s/it]No handles with labels found to put in legend.
# 195it [35:38, 16.48s/it]No handles with labels found to put in legend.
# 196it [36:00, 18.31s/it]No handles with labels found to put in legend.
# 197it [36:19, 18.56s/it]No handles with labels found to put in legend.
# 198it [36:40, 19.24s/it]No handles with labels found to put in legend.
# 199it [36:59, 19.02s/it]No handles with labels found to put in legend.
# 200it [37:23, 20.57s/it]No handles with labels found to put in legend.
# 201it [37:43, 20.49s/it]No handles with labels found to put in legend.
# 202it [38:02, 20.08s/it]No handles with labels found to put in legend.
# 203it [38:14, 17.47s/it]No handles with labels found to put in legend.
# 204it [38:23, 14.92s/it]No handles with labels found to put in legend.
# 205it [38:41, 15.83s/it]No handles with labels found to put in legend.
# 206it [39:00, 16.88s/it]No handles with labels found to put in legend.
# 207it [39:15, 16.32s/it]No handles with labels found to put in legend.
# 208it [39:27, 15.10s/it]No handles with labels found to put in legend.
# 209it [39:47, 16.54s/it]No handles with labels found to put in legend.
# 210it [40:09, 18.06s/it]No handles with labels found to put in legend.
# 211it [40:32, 19.57s/it]No handles with labels found to put in legend.
# 212it [40:50, 19.01s/it]No handles with labels found to put in legend.
# 213it [41:01, 16.76s/it]No handles with labels found to put in legend.
# 214it [41:16, 16.25s/it]No handles with labels found to put in legend.
# 215it [41:37, 17.53s/it]No handles with labels found to put in legend.
# 216it [41:53, 17.13s/it]No handles with labels found to put in legend.
# 217it [42:10, 17.16s/it]No handles with labels found to put in legend.
# 218it [42:20, 14.83s/it]No handles with labels found to put in legend.
# 219it [42:39, 16.31s/it]No handles with labels found to put in legend.
# 220it [42:59, 17.39s/it]No handles with labels found to put in legend.
# 221it [43:12, 15.98s/it]No handles with labels found to put in legend.
# 222it [43:21, 13.78s/it]No handles with labels found to put in legend.
# 223it [43:25, 10.92s/it]No handles with labels found to put in legend.
# 224it [43:32,  9.80s/it]No handles with labels found to put in legend.
# 225it [43:46, 10.99s/it]No handles with labels found to put in legend.
# 226it [43:55, 10.33s/it]No handles with labels found to put in legend.
# 227it [44:10, 11.97s/it]No handles with labels found to put in legend.
# 228it [44:19, 10.95s/it]No handles with labels found to put in legend.
# 229it [44:23,  8.94s/it]No handles with labels found to put in legend.
# 230it [44:40, 11.17s/it]No handles with labels found to put in legend.
# 231it [44:54, 12.31s/it]No handles with labels found to put in legend.
# 232it [45:10, 13.13s/it]No handles with labels found to put in legend.
# 233it [45:26, 14.28s/it]No handles with labels found to put in legend.
# 234it [45:47, 16.11s/it]No handles with labels found to put in legend.
# 235it [45:53, 13.13s/it]No handles with labels found to put in legend.
# 236it [46:06, 12.97s/it]No handles with labels found to put in legend.
# 237it [46:15, 11.83s/it]No handles with labels found to put in legend.
# 238it [46:28, 12.15s/it]No handles with labels found to put in legend.
# 239it [46:42, 12.72s/it]No handles with labels found to put in legend.
# 240it [46:57, 13.43s/it]No handles with labels found to put in legend.
# 241it [47:11, 13.59s/it]No handles with labels found to put in legend.
# 242it [47:25, 13.71s/it]No handles with labels found to put in legend.
# 243it [47:32, 11.70s/it]No handles with labels found to put in legend.
# 244it [47:44, 11.74s/it]No handles with labels found to put in legend.
# 245it [48:02, 13.60s/it]No handles with labels found to put in legend.
# 246it [48:11, 12.28s/it]No handles with labels found to put in legend.
# 247it [48:25, 12.89s/it]No handles with labels found to put in legend.
# 248it [48:33, 11.43s/it]No handles with labels found to put in legend.
# 249it [48:46, 11.72s/it]No handles with labels found to put in legend.
# 250it [48:55, 11.01s/it]No handles with labels found to put in legend.
# 251it [49:10, 12.30s/it]No handles with labels found to put in legend.
# 252it [49:16, 10.39s/it]No handles with labels found to put in legend.
# 253it [49:26, 10.17s/it]No handles with labels found to put in legend.
# 254it [49:36, 10.23s/it]No handles with labels found to put in legend.
# 255it [49:48, 10.68s/it]No handles with labels found to put in legend.
# 256it [50:02, 11.78s/it]No handles with labels found to put in legend.
# 257it [50:16, 12.46s/it]No handles with labels found to put in legend.
# 258it [50:26, 11.71s/it]No handles with labels found to put in legend.
# 259it [50:41, 12.68s/it]No handles with labels found to put in legend.
# 260it [50:47, 10.61s/it]No handles with labels found to put in legend.
# 261it [50:56, 10.12s/it]No handles with labels found to put in legend.
# 262it [51:01,  8.50s/it]No handles with labels found to put in legend.
# 263it [51:12,  9.45s/it]No handles with labels found to put in legend.
# 264it [51:27, 11.08s/it]No handles with labels found to put in legend.
# 265it [51:33,  9.36s/it]No handles with labels found to put in legend.
# 266it [51:46, 10.46s/it]No handles with labels found to put in legend.
# 267it [52:03, 12.40s/it]No handles with labels found to put in legend.
# 268it [52:18, 13.21s/it]No handles with labels found to put in legend.
# 269it [52:32, 13.55s/it]No handles with labels found to put in legend.
# 270it [52:48, 14.42s/it]No handles with labels found to put in legend.
# 271it [52:53, 11.39s/it]No handles with labels found to put in legend.
# 272it [53:09, 13.00s/it]No handles with labels found to put in legend.
# 273it [53:27, 14.24s/it]No handles with labels found to put in legend.
# 274it [53:43, 14.90s/it]No handles with labels found to put in legend.
# 275it [54:02, 16.13s/it]No handles with labels found to put in legend.
# 276it [54:20, 16.70s/it]No handles with labels found to put in legend.
# 277it [54:36, 16.39s/it]No handles with labels found to put in legend.
# 278it [54:50, 15.62s/it]No handles with labels found to put in legend.
# 279it [55:02, 14.75s/it]No handles with labels found to put in legend.
# 280it [55:25, 17.23s/it]No handles with labels found to put in legend.
# 281it [55:29, 13.23s/it]No handles with labels found to put in legend.
# 282it [55:46, 14.34s/it]No handles with labels found to put in legend.
# 283it [55:56, 12.98s/it]No handles with labels found to put in legend.
# 284it [56:13, 14.29s/it]No handles with labels found to put in legend.
# 285it [56:28, 14.45s/it]No handles with labels found to put in legend.
# 286it [56:43, 14.66s/it]No handles with labels found to put in legend.
# 287it [56:49, 12.08s/it]No handles with labels found to put in legend.
# 288it [57:01, 11.88s/it]

# %%
def SigDiffON_OFF(sessionfile,clust):
    allConditions = ilep.getAllConditions(sessionfile,clust,trialsPerDayLoaded = 'NO_TRIM')
    on_trials = allConditions['laser_on'].trials
    off_trials = allConditions['laser_off'].trials
    
    FR_on = []
    for trial in on_trials:
        starttime = sessionfile.trials.starts[trial]
        endtime = sessionfile.trials.starts[trial] + 0.1*sessionfile.meta.fs
        spikeTimes = ilep.getSpikeTimes(sessionfile,clust=clust,starttime=starttime,endtime=endtime)
        FR = len(spikeTimes) / 0.1
        FR_on.append(FR)
        
    FR_off = []
    for trial in off_trials:
        starttime = sessionfile.trials.starts[trial]
        endtime = sessionfile.trials.starts[trial] + 0.1*sessionfile.meta.fs
        spikeTimes = ilep.getSpikeTimes(sessionfile,clust=clust,starttime=starttime,endtime=endtime)
        FR = len(spikeTimes) / 0.1
        FR_off.append(FR)
        
    return mannwhitneyu(FR_on,FR_off).pvalue

def SigDiffON_OFF_control(sessionfile,clust):
    allConditions = ilep.getAllConditions(sessionfile,clust,trialsPerDayLoaded = 'NO_TRIM')
    on_trials = allConditions['even'].trials
    off_trials = allConditions['odd'].trials
    
    FR_on = []
    for trial in on_trials:
        starttime = sessionfile.trials.starts[trial]
        endtime = sessionfile.trials.starts[trial] + 0.1*sessionfile.meta.fs
        spikeTimes = ilep.getSpikeTimes(sessionfile,clust=clust,starttime=starttime,endtime=endtime)
        FR = len(spikeTimes) / 0.1
        FR_on.append(FR)
        
    FR_off = []
    for trial in off_trials:
        starttime = sessionfile.trials.starts[trial]
        endtime = sessionfile.trials.starts[trial] + 0.1*sessionfile.meta.fs
        spikeTimes = ilep.getSpikeTimes(sessionfile,clust=clust,starttime=starttime,endtime=endtime)
        FR = len(spikeTimes) / 0.1
        FR_off.append(FR)
        
    return mannwhitneyu(FR_on,FR_off).pvalue

# %%
depths = []

for idx,(session,clust) in tqdm(enumerate(zip(EnumSession,EnumClust))):
    sessionfile = ilep.loadSessionCached(ops_directory,session)
    n = len(EnumClust)
    
    p = SigDiffON_OFF_control(sessionfile,clust)
    ### MC Corrections
    if(p*n)<0.05:
        print(f"{session} clust {clust} p_unc = {p} p_corr = {p*n}, depth = {sessionfile.clusters.depth[clust]}")
        depths.append(sessionfile.clusters.depth[clust])
# Out:
# 288it [01:38,  2.94it/s]
