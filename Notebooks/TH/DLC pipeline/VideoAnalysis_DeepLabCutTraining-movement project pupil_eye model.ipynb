# %% [markdown]
# # Step1: Import modules

# %% [markdown]
# Run this code in conda Deeplabcut environment
# https://www.nature.com/articles/s41596-019-0176-0#Sec14

# %%
try:
    import deeplabcut
    import tensorflow
    import tkinter
    from tkinter import filedialog

    print(f'Using DeepLabCut version: {deeplabcut. __version__}')
    print(f'Using TensorFlow version: {tensorflow. __version__}')   

except:
    print("Please run the notebook in in your local environment")
# Out:
# Loading DLC 2.3.9...
# Using DeepLabCut version: 2.3.9
# Using TensorFlow version: 2.10.0

# %% [markdown]
# # Step2:Training

# %% [markdown]
# Create a new training project, then open config.yaml file and change the parameters
# Extrace frames from all videos so we can create a training dataset
#
# Training model:
# Label frames to manually mark the bodyparts in GUI
# Check labels

# %% [markdown]
# In this code, the training dataset includes 7 videos. They are added one by one.
# Crop each video around the eyes.
#
# To crop each video, you need to change the parameters in the config file, under 'crop:'. Each video may have different cropping values, so run and interrupt deeplabcut.CropVideo to help you choosing good cropping values.

# %% [markdown]
# ### video2

# %%
video_directory= ['C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 02.mp4'
                 ]

# %%
config_path = 'C:\\Users\insan\\Desktop\\Motion project training\\Training_nonmulti\\Training_project-TH-2024-04-09\\config.yaml'

# %%
#already create, do not run again,run config_path above instead
config_path = deeplabcut.create_new_project('Training_project', 'TH', video_directory, working_directory='C:\\Users\insan\\Desktop\\Motion project training\\Training_nonmulti', copy_videos=False, multianimal=False)
# Out:
# Created "C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-10\videos"
# Created "C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-10\labeled-data"
# Created "C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-10\training-datasets"
# Created "C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-10\dlc-models"
# Attempting to create a symbolic link of the video ...
# Symlink creation impossible (exFat architecture?): copying the video instead.
# C:\Users\insan\Desktop\Motion project training\Training_videos\Training 02.mp4 copied to C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-10\videos\Training 02.mp4
# C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-10\videos\Training 02.mp4
# Generated "C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-10\config.yaml"
#
# A new project with name Training_project-TH-2024-04-10 is created at C:\Users\insan\Desktop\Motion project training\Training_nonmulti and a configurable file (config.yaml) is stored there. Change the parameters in this file to adapt to your project's needs.
#  Once you have changed the configuration file, use the function 'extract_frames' to select frames for labeling.
# . [OPTIONAL] Use the function 'add_new_videos' to add new videos to your project (at any stage).

# %%
# this image helps with set cropping parameters

# deeplabcut.CropVideo(
#     'C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 02.mp4',
#     width=350,
#     height=350,
#     origin_x=400,
#     origin_y=200,
#     outsuffix='cropped',
#     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#     useGUI=True,
# )
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     'C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 02.mp4',
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %%
#Video name: training 02

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True)
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 38.16  seconds.
# Extracting and downsampling... 2290  frames from the video.
# 2290it [00:07, 301.37it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True)
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 1144.74  seconds to 1182.9  seconds.
# Extracting and downsampling... 2290  frames from the video.
# 2290it [00:07, 298.65it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True)
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 1430.92  seconds to 1526.32  seconds.
# Extracting and downsampling... 5725  frames from the video.
# 5725it [00:18, 304.71it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.label_frames(config_path)

# %%
config_path
# Out:
# 'C:\\Users\\insan\\Desktop\\Motion project training\\Training_project-TH-2024-04-09\\config.yaml'

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by TH.
# 100%|██████████| 53/53 [00:01<00:00, 30.16it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# ### video3

# %%
deeplabcut.add_new_videos(config_path, ['C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 03.mp4'],copy_videos=False,coords=None,extract_frames=False)
# Out:
# Attempting to create a symbolic link of the video ...
# Video C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\videos\Training 03.mp4 already exists. Skipping...
# New videos were added to the project! Use the function 'extract_frames' to select frames for labeling.

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.75-0.8 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 1430.92  seconds to 1526.32  seconds.
# Extracting and downsampling... 5725  frames from the video.
# 5725it [00:20, 275.94it/s]
# Kmeans clustering ... (this might take a while)
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 971.35  seconds to 1036.11  seconds.
# Extracting and downsampling... 3886  frames from the video.
# 3886it [00:15, 257.53it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.1-0.2 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 129.51  seconds to 259.03  seconds.
# Extracting and downsampling... 7772  frames from the video.
# 7772it [00:28, 269.79it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.4-0.7 40frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 518.05  seconds to 906.59  seconds.
# Extracting and downsampling... 23313  frames from the video.
# 23313it [01:27, 267.71it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.label_frames(config_path)

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by TH.
# 100%|██████████| 70/70 [00:02<00:00, 33.24it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# ### video4

# %%
deeplabcut.add_new_videos(config_path, ['C:\\Users\insan\\Desktop\\Motion project training\\Videos\\Training 04.mp4'],copy_videos=False,coords=None,extract_frames=False)
# Out:
# Attempting to create a symbolic link of the video ...
# Symlink creation impossible (exFat architecture?): copying the video instead.
# C:\Users\insan\Desktop\Motion project training\Videos\Training 04.mp4 copied to C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\videos\Training 04.mp4
# New videos were added to the project! Use the function 'extract_frames' to select frames for labeling.

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.75-0.8 16frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 1381.01  seconds to 1473.08  seconds.
# Extracting and downsampling... 5525  frames from the video.
# 5525it [00:19, 288.27it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.1-0.2 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 184.14  seconds to 368.27  seconds.
# Extracting and downsampling... 11049  frames from the video.
# 11049it [00:39, 280.62it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.4-0.7 40frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 736.54  seconds to 1288.94  seconds.
# Extracting and downsampling... 33145  frames from the video.
# 33145it [02:02, 269.59it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
# deeplabcut.CropVideo(
#     'C:\\Users\insan\\Desktop\\Motion project training\\Videos\\Training 04.mp4',
#     width=450,
#     height=800,
#     origin_x=200,
#     origin_y=400,
#     outsuffix='cropped',
#     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#     useGUI=True,
# )
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     'C:\\Users\insan\\Desktop\\Motion project training\\Videos\\Training 04.mp4',
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %%
deeplabcut.label_frames(config_path)

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by TH.
# 100%|██████████| 71/71 [00:02<00:00, 34.25it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# ### Video5

# %%
deeplabcut.add_new_videos(config_path, ['C:\\Users\insan\\Desktop\\Motion project training\\Videos\\Training 05.mp4'],copy_videos=False,coords=None,extract_frames=False)
# Out:
# Attempting to create a symbolic link of the video ...
# Symlink creation impossible (exFat architecture?): copying the video instead.
# C:\Users\insan\Desktop\Motion project training\Videos\Training 05.mp4 copied to C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\videos\Training 05.mp4
# New videos were added to the project! Use the function 'extract_frames' to select frames for labeling.

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.75-0.8 16frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 1277.28  seconds to 1362.43  seconds.
# Extracting and downsampling... 5110  frames from the video.
# 5110it [00:18, 281.39it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.2-0.3 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 340.61  seconds to 510.91  seconds.
# Extracting and downsampling... 10219  frames from the video.
# 10219it [00:36, 282.26it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.4-0.7 40frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 681.21  seconds to 1192.12  seconds.
# Extracting and downsampling... 30656  frames from the video.
# 30656it [01:49, 280.76it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
# deeplabcut.CropVideo(
#     'C:\\Users\insan\\Desktop\\Motion project training\\Videos\\Training 05.mp4',
#     width=800-450,
#     height=400-200,
#     origin_x=450,
#     origin_y=200,
#     outsuffix='cropped',
#     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#     useGUI=True,
# )
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     'C:\\Users\insan\\Desktop\\Motion project training\\Videos\\Training 05.mp4',
#       3     width=800-450,
#       4     height=400-200,
#       5     origin_x=450,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %%
deeplabcut.label_frames(config_path)
# Out:
# delete_selected_points() missing 1 required positional argument: 'layer'
# Traceback (most recent call last):
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\in_n_out\_store.py", line 805, in _exec
#     result = func(**bound.arguments)
# TypeError: delete_selected_points() missing 1 required positional argument: 'layer'
# _get_current_activity_dock() missing 1 required positional argument: 'window'
# Traceback (most recent call last):
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\in_n_out\_store.py", line 805, in _exec
#     result = func(**bound.arguments)
# TypeError: _get_current_activity_dock() missing 1 required positional argument: 'window'
# _get_current_activity_dock() missing 1 required positional argument: 'window'
# Traceback (most recent call last):
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\in_n_out\_store.py", line 805, in _exec
#     result = func(**bound.arguments)
# TypeError: _get_current_activity_dock() missing 1 required positional argument: 'window'
# _toggle_play() missing 1 required positional argument: 'self'
# Traceback (most recent call last):
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\in_n_out\_store.py", line 805, in _exec
#     result = func(**bound.arguments)
# TypeError: _toggle_play() missing 1 required positional argument: 'self'
# _get_current_activity_dock() missing 1 required positional argument: 'window'
# Traceback (most recent call last):
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\in_n_out\_store.py", line 805, in _exec
#     result = func(**bound.arguments)
# TypeError: _get_current_activity_dock() missing 1 required positional argument: 'window'
# _toggle_play() missing 1 required positional argument: 'self'
# Traceback (most recent call last):
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\in_n_out\_store.py", line 805, in _exec
#     result = func(**bound.arguments)
# TypeError: _toggle_play() missing 1 required positional argument: 'self'

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by TH.
# 100%|██████████| 71/71 [00:01<00:00, 36.68it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# ### Video6

# %%
deeplabcut.add_new_videos(config_path, ['C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 06.mp4'],copy_videos=False,coords=None,extract_frames=False)
# Out:
# Attempting to create a symbolic link of the video ...
# Symlink creation impossible (exFat architecture?): copying the video instead.
# C:\Users\insan\Desktop\Motion project training\Training_videos\Training 06.mp4 copied to C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\videos\Training 06.mp4
# New videos were added to the project! Use the function 'extract_frames' to select frames for labeling.

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0-0.01 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 24.71  seconds.
# Extracting and downsampling... 1483  frames from the video.
# 1483it [00:05, 273.92it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.01-0.02 5frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 24.71  seconds to 49.42  seconds.
# Extracting and downsampling... 1484  frames from the video.
# 1484it [00:05, 278.48it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.4-0.6 30frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 988.37  seconds to 1482.56  seconds.
# Extracting and downsampling... 29652  frames from the video.
# 29652it [01:49, 270.01it/s]
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
# deeplabcut.CropVideo(
#     'C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 06.mp4',
#     width=350,
#     height=150,
#     origin_x=450,
#     origin_y=200,
#     outsuffix='cropped',
#     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#     useGUI=True,
# )
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     'C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 06.mp4',
#       3     width=800-450,
#       4     height=400-200,
#       5     origin_x=450,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %%
deeplabcut.label_frames(config_path)

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by TH.
# 100%|██████████| 50/50 [00:01<00:00, 29.35it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# ### video7

# %%
deeplabcut.add_new_videos(config_path, ['C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 07.mp4'],copy_videos=False,coords=None,extract_frames=False)
# Out:
# Attempting to create a symbolic link of the video ...
# Symlink creation impossible (exFat architecture?): copying the video instead.
# C:\Users\insan\Desktop\Motion project training\Training_videos\Training 07.mp4 copied to C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\videos\Training 07.mp4
# New videos were added to the project! Use the function 'extract_frames' to select frames for labeling.

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0-0.3 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 674.27  seconds.
# Extracting and downsampling... 40457  frames from the video.
# 40457it [02:24, 280.15it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.5-0.65 20frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 1123.78  seconds to 1460.92  seconds.
# Extracting and downsampling... 20229  frames from the video.
# 20229it [01:07, 301.15it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.label_frames(config_path)

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by TH.
# 100%|██████████| 35/35 [00:01<00:00, 34.90it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# ### video8

# %%
deeplabcut.add_new_videos(config_path, ['C:\\Users\insan\\Desktop\\Motion project training\\Training_videos\\Training 08.mp4'],copy_videos=False,coords=None,extract_frames=False)
# Out:
# Attempting to create a symbolic link of the video ...
# Symlink creation impossible (exFat architecture?): copying the video instead.
# C:\Users\insan\Desktop\Motion project training\Training_videos\Training 08.mp4 copied to C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\videos\Training 08.mp4
# New videos were added to the project! Use the function 'extract_frames' to select frames for labeling.

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0-0.2 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 339.46  seconds.
# Extracting and downsampling... 20368  frames from the video.
# 20368it [01:16, 265.02it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False,crop=True) #0.7-0.9 15frames
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 1188.11  seconds to 1527.57  seconds.
# Extracting and downsampling... 20369  frames from the video.
# 20369it [01:15, 270.47it/s]
# Kmeans clustering ... (this might take a while)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).

# %%
deeplabcut.label_frames(config_path)

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by TH.
# 100%|██████████| 30/30 [00:00<00:00, 31.38it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# # Step3: create training model

# %%
#Create a training dataset
#Train the network with 500K iterations
#Evaluate the network

# %%
#7videos

# %%
#53+70+71+71+50+35+30

# %%
deeplabcut.create_training_dataset(config_path, augmenter_type='imgaug')
# Out:
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# [(0.95,
#   1,
#   (array([117, 219, 351, 193, 334,   4, 114,  57, 366, 278, 202, 217,  30,
#           158, 138, 155,  21, 346,  67,  93, 161, 213, 327, 172, 317, 170,
#           103,  91, 125,  10, 330, 198,  32, 355,  37, 274, 147,  58, 378,
#            86, 240, 104,  72,  68,  85, 183,  17, 127, 199,  18, 221, 347,
#            62, 235,  51, 302, 159, 244, 177, 111, 295, 220, 184, 338, 246,
#           316,  87, 307, 376, 171,  59, 230,  22, 192,  89,  64, 116, 134,
#           298, 365, 174,   8, 318, 166, 249, 353,  52, 157, 290, 123, 284,
#           247, 204, 163,  13, 268, 289,  11, 223, 297, 305, 266, 185, 379,
#           308, 280, 227, 345, 272, 311, 128,  50,  33, 275, 356, 293, 196,
#           273, 143, 321, 254,  38, 181, 371, 287, 374,  63,  94,   1, 100,
#           208, 352, 189, 188, 277, 153, 210, 191, 253,  29, 288,  39, 303,
#           234, 197, 312, 187, 367, 314, 236,  83, 107,  78, 232, 285, 248,
#           180, 154, 243,  56, 112,  41,  20,  47, 150, 322, 375,  46, 228,
#           281, 323, 256, 190, 106,  43, 131,  48, 359, 133,  23,  79, 139,
#           179,  84, 370, 165, 361, 146, 325, 331, 141,  49, 257, 267, 108,
#           329, 167,  92, 200, 313, 225, 292, 124, 182,  81,  15, 324, 206,
#           130,  35,  24,  19, 156,  98, 105, 373,  16, 173, 120, 261,   3,
#           160, 377, 168, 258,  61, 279, 121, 344, 151, 222, 354,   9, 122,
#            88, 129, 162, 250, 339, 239, 119,  27, 337, 110, 101, 304, 343,
#           216,  73, 201, 211, 349, 137, 212,   2,  71,  77, 115,  55, 341,
#           148, 205,  66, 291,  34, 203, 335,  69,  25,  99, 126, 144, 342,
#           309, 262, 286, 260, 283, 310, 142, 229,  28,  60, 178, 358, 186,
#           102, 357, 241, 175, 209, 332, 263, 218,  40,   5,   0,   7,  45,
#           348,  74, 269, 215, 362, 255, 270,   6, 315, 294,  54, 251, 368,
#           320, 306, 252, 214, 233,  97, 363, 350,  70,  12, 364, 300, 301,
#           149, 226,  26,  53, 340, 109, 369, 299, 140,  44, 169, 265, 282,
#           242, 372,  65, 145, 224, 264, 336,  42,  14, 195, 296, 113,  75,
#           238,  76,  95,  31, 271, 194, 259, 152, 276,  36]),
#    array([326, 135, 132, 328, 245, 360, 207, 164, 333,  90, 176, 118,  82,
#           136, 237, 319,  96,  80, 231])))]

# %%
deeplabcut.train_network(config_path, shuffle=1, trainingsetindex=0, max_snapshots_to_keep=5, autotune=False, displayiters=100, saveiters=10000, maxiters=500000, allow_growth=True)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'contrast': {'clahe': True,
#               'claheratio': 0.1,
#               'histeq': True,
#               'histeqratio': 0.1},
#  'convolution': {'edge': False,
#                  'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]},
#                  'embossratio': 0.1,
#                  'sharpen': False,
#                  'sharpenratio': 0.3},
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'decay_steps': 30000,
#  'deterministic': False,
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'lr_init': 0.0005,
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Documentation_data-Training_project_95shuffle1.pickle',
#  'min_input_size': 64,
#  'mirror': False,
#  'multi_stage': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': False,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\insan\\Desktop\\Motion project '
#                  'training\\Training_nonmulti\\Training_project-TH-2024-04-09',
#  'regularize': False,
#  'rotation': 25,
#  'rotratio': 0.4,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\train\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Selecting single-animal trainer
# Batch Size is 1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Loading ImageNet-pretrained resnet_50
# Max_iters overwritten as 500000
# Display_iters overwritten as 100
# Save_iters overwritten as 10000
# Training parameter:
# {'stride': 8.0, 'weigh_part_predictions': False, 'weigh_negatives': False, 'fg_fraction': 0.25, 'mean_pixel': [123.68, 116.779, 103.939], 'shuffle': True, 'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\train\\snapshot', 'log_dir': 'log', 'global_scale': 0.8, 'location_refinement': True, 'locref_stdev': 7.2801, 'locref_loss_weight': 0.05, 'locref_huber_loss': True, 'optimizer': 'sgd', 'intermediate_supervision': False, 'intermediate_supervision_layer': 12, 'regularize': False, 'weight_decay': 0.0001, 'crop_pad': 0, 'scoremap_dir': 'test', 'batch_size': 1, 'dataset_type': 'imgaug', 'deterministic': False, 'mirror': False, 'pairwise_huber_loss': False, 'weigh_only_present_joints': False, 'partaffinityfield_predict': False, 'pairwise_predict': False, 'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]], 'all_joints_names': ['Pupilup', 'Pupildown', 'Pupilleft', 'Pupilright', 'Eyelidup', 'Eyeliddown', 'Eyelidleft', 'Eyelidright'], 'alpha_r': 0.02, 'apply_prob': 0.5, 'contrast': {'clahe': True, 'claheratio': 0.1, 'histeq': True, 'histeqratio': 0.1, 'gamma': False, 'sigmoid': False, 'log': False, 'linear': False}, 'convolution': {'edge': False, 'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]}, 'embossratio': 0.1, 'sharpen': False, 'sharpenratio': 0.3}, 'cropratio': 0.4, 'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat', 'decay_steps': 30000, 'display_iters': 1000, 'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt', 'lr_init': 0.0005, 'max_input_size': 1500, 'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Documentation_data-Training_project_95shuffle1.pickle', 'min_input_size': 64, 'multi_stage': False, 'multi_step': [[0.005, 10000], [0.02, 430000], [0.002, 730000], [0.001, 1030000]], 'net_type': 'resnet_50', 'num_joints': 8, 'pos_dist_thresh': 17, 'project_path': 'C:\\Users\\insan\\Desktop\\Motion project training\\Training_nonmulti\\Training_project-TH-2024-04-09', 'rotation': 25, 'rotratio': 0.4, 'save_iters': 50000, 'scale_jitter_lo': 0.5, 'scale_jitter_up': 1.25, 'covering': True, 'elastic_transform': True, 'motion_blur': True, 'motion_blur_params': {'k': 7, 'angle': (-90, 90)}}
# Starting training....
# iteration: 100 loss: 0.0981 lr: 0.005
# iteration: 200 loss: 0.0438 lr: 0.005
# iteration: 300 loss: 0.0356 lr: 0.005
# iteration: 400 loss: 0.0309 lr: 0.005
# iteration: 500 loss: 0.0287 lr: 0.005
# iteration: 600 loss: 0.0275 lr: 0.005
# iteration: 700 loss: 0.0248 lr: 0.005
# iteration: 800 loss: 0.0232 lr: 0.005
# iteration: 900 loss: 0.0225 lr: 0.005
# iteration: 1000 loss: 0.0227 lr: 0.005
# iteration: 1100 loss: 0.0214 lr: 0.005
# iteration: 1200 loss: 0.0199 lr: 0.005
# iteration: 1300 loss: 0.0193 lr: 0.005
# iteration: 1400 loss: 0.0193 lr: 0.005
# iteration: 1500 loss: 0.0190 lr: 0.005

#     File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\pose_estimation_tensorflow\training.py", line 273, in train_network
#       train(
#     File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\pose_estimation_tensorflow\core\train.py", line 172, in train
#       batch, enqueue_op, placeholders = setup_preloading(batch_spec)
#     File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\pose_estimation_tensorflow\core\train.py", line 72, in setup_preloading
#       enqueue_op = q.enqueue(placeholders_list)
# Node: 'fifo_queue_enqueue'
# Enqueue operation was cancelled
# 	 [[{{node fifo_queue_enqueue}}]]
#
# Original stack trace for 'fifo_queue_enqueue':
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\IPython\core\interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\IPython\core\interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\insan\AppData\Local\Temp\ipykernel_10724\554959732.py", line 1, in <module>
#     deeplabcut.train_network(config_path, shuffle=1, trainingsetindex=0, max_snapshots_to_keep=5, autotune=False, displayiters=100, saveiters=10000, maxiters=500000, allow_growth=True)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\pose_estimation_tensorflow\training.py", line 273, in train_network
#     train(
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\pose_estimation_tensorflow\core\train.py", line 172, in train
#     batch, enqueue_op, placeholders = setup_preloading(batch_spec)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\pose_estimation_tensorflow\core\train.py", line 72, in setup_preloading
#     enqueue_op = q.enqueue(placeholders_list)
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\ops\data_flow_ops.py", line 346, in enqueue
#     return gen_data_flow_ops.queue_enqueue_v2(
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py", line 4062, in queue_enqueue_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 797, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\framework\ops.py", line 3800, in _create_op_internal
#     ret = Operation(
# The network is now trained and ready to evaluate. Use the function 'evaluate_network' to evaluate the network.

# %%
deeplabcut.evaluate_network(config_path,plotting=True)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'contrast': {'clahe': True,
#               'claheratio': 0.1,
#               'histeq': True,
#               'histeqratio': 0.1},
#  'convolution': {'edge': False,
#                  'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]},
#                  'embossratio': 0.1,
#                  'sharpen': False,
#                  'sharpenratio': 0.3},
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'decay_steps': 30000,
#  'deterministic': False,
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'lr_init': 0.0005,
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Documentation_data-Training_project_95shuffle1.pickle',
#  'min_input_size': 64,
#  'mirror': False,
#  'multi_stage': False,
#  'multi_step': [[0.005, 10000],
#                 [0.02, 430000],
#                 [0.002, 730000],
#                 [0.001, 1030000]],
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': False,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'pos_dist_thresh': 17,
#  'project_path': 'C:\\Users\\insan\\Desktop\\Motion project '
#                  'training\\Training_nonmulti\\Training_project-TH-2024-04-09',
#  'regularize': False,
#  'rotation': 25,
#  'rotratio': 0.4,
#  'save_iters': 50000,
#  'scale_jitter_lo': 0.5,
#  'scale_jitter_up': 1.25,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\train\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Running  DLC_resnet50_Training_projectApr9shuffle1_500000  with # of training iterations: 500000
# Running evaluation ...
# 380it [00:11, 32.14it/s]
# Analysis is done and the results are stored (see evaluation-results) for snapshot:  snapshot-500000
# Results for 500000  training iterations: 95 1 train error: 1.38 pixels. Test error: 2.31  pixels.
# With pcutoff of 0.6  train error: 1.38 pixels. Test error: 2.31 pixels
# Thereby, the errors are given by the average distances between the labels by DLC and the scorer.
# Plotting...
# 100%|██████████| 380/380 [00:29<00:00, 13.10it/s]
# The network is evaluated and the results are stored in the subdirectory 'evaluation_results'.
# Please check the results, then choose the best model (snapshot) for prediction. You can update the config.yaml file with the appropriate index for the 'snapshotindex'.
# Use the function 'analyze_video' to make predictions on new videos.
# Otherwise, consider adding more labeled-data and retraining the network (see DeepLabCut workflow Fig 2, Nath 2019)

# %% [markdown]
# # Step4: label new videos with the trained model and see results

# %%
video_file1 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video_skeleton\\Test1_309.mp4'

# %%
video1 = deeplabcut.analyzeskeleton(config_path, [video_file1],videotype='.mp4',save_as_csv=True)
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video_skeleton\Test1_309.mp4

# %% [markdown]
# ## video1

# %%
video_file1 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video1\\Test1_309.mp4'

# %%
# deeplabcut.CropVideo(
#     video_file1,
#     width=350,
#     height=350,
#     origin_x=400,
#     origin_y=200,
#     outsuffix='cropped',
#     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#     useGUI=True,
# )
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     video_file1,
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %%
video1 = deeplabcut.analyze_videos(config_path, [video_file1],videotype='.mp4',auto_track=True,save_as_csv=True,cropping= [250,600,200,500])
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Overwriting cropping parameters: [250, 600, 200, 500]
# These are used for all videos, but won't be save to the cfg file.
# Using snapshot-500000 for model C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\dlc-models\iteration-0\Training_projectApr9-trainset95shuffle1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  C:\Users\insan\Desktop\Motion project training\Analysis_video1\Test1_309.mp4
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video1\Test1_309.mp4
# Duration of video [s]:  34.58 , recorded with  60.0 fps!
# Overall # of frames:  2075  found with (before cropping) frame dimensions:  1080 1080
# Starting to extract posture
# Cropping based on the x1 = 250 x2 = 600 y1 = 200 y2 = 500. You can adjust the cropping coordinates in the config.yaml file.
# 100%|██████████| 2075/2075 [00:25<00:00, 79.91it/s]
# Saving results in C:\Users\insan\Desktop\Motion project training\Analysis_video1...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %%
deeplabcut.create_labeled_video(config_path, [video_file1], save_frames = True,displaycropped=True)
# Out:
# Starting to process video: C:\Users\insan\Desktop\Motion project training\Analysis_video1\Test1_309.mp4
# Loading C:\Users\insan\Desktop\Motion project training\Analysis_video1\Test1_309.mp4 and data.
# Duration of video [s]: 34.58, recorded with 60.0 fps!
# Overall # of frames: 2075 with cropped frame dimensions: 350 300
# Generating frames and creating video.
# 100%|██████████| 2075/2075 [04:21<00:00,  7.92it/s]
# Labeled video C:\Users\insan\Desktop\Motion project training\Analysis_video1\Test1_309DLC_resnet50_Training_projectApr9shuffle1_500000_labeled.mp4 successfully created.
# [True]

# %%
deeplabcut.plot_trajectories(config_path,[video_file1], videotype='.mp4')
# Out:
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video1\Test1_309.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %% [markdown]
# ## video2

# %%
video_file2 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video2\\Test2_310.mp4'

# %%
deeplabcut.CropVideo(
    video_file2,
    width=350,
    height=350,
    origin_x=400,
    origin_y=200,
    outsuffix='cropped',
    outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
    useGUI=True,
)
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     video_file2,
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %%
video2 = deeplabcut.analyze_videos(config_path, [video_file2],videotype='.mp4',auto_track=True,save_as_csv=True,cropping= [210,600,170,550])
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Overwriting cropping parameters: [210, 600, 170, 550]
# These are used for all videos, but won't be save to the cfg file.
# Using snapshot-500000 for model C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\dlc-models\iteration-0\Training_projectApr9-trainset95shuffle1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  C:\Users\insan\Desktop\Motion project training\Analysis_video2\Test2_310.mp4
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video2\Test2_310.mp4
# Duration of video [s]:  395.03 , recorded with  60.0 fps!
# Overall # of frames:  23702  found with (before cropping) frame dimensions:  1080 1080
# Starting to extract posture
# Cropping based on the x1 = 210 x2 = 600 y1 = 170 y2 = 550. You can adjust the cropping coordinates in the config.yaml file.
# 100%|██████████| 23702/23702 [05:42<00:00, 69.26it/s]
# Saving results in C:\Users\insan\Desktop\Motion project training\Analysis_video2...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %%
deeplabcut.create_labeled_video(config_path, [video_file2], save_frames = True,displaycropped=True)
# Out:
# Starting to process video: C:\Users\insan\Desktop\Motion project training\Analysis_video2\Test2_310.mp4
# Loading C:\Users\insan\Desktop\Motion project training\Analysis_video2\Test2_310.mp4 and data.
# Duration of video [s]: 395.03, recorded with 60.0 fps!
# Overall # of frames: 23702 with cropped frame dimensions: 390 380
# Generating frames and creating video.
# 100%|██████████| 23702/23702 [56:56<00:00,  6.94it/s]
# Labeled video C:\Users\insan\Desktop\Motion project training\Analysis_video2\Test2_310DLC_resnet50_Training_projectApr9shuffle1_500000_labeled.mp4 successfully created.
# [True]

# %%
deeplabcut.plot_trajectories(config_path,[video_file2], videotype='.mp4')
# Out:
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video2\Test2_310.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
deeplabcut.analyzeskeleton(config_path, [video_file2],videotype='.mp4',save_as_csv=True)
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video2\Test2_310.mp4

# %% [markdown]
# ## video3

# %%
video_file3 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video3\\Test3_310.mp4'

# %%
video3 = deeplabcut.analyze_videos(config_path, [video_file3],videotype='.mp4',auto_track=True,save_as_csv=True,cropping= [240,600, 200, 400 ])
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Overwriting cropping parameters: [240, 600, 200, 400]
# These are used for all videos, but won't be save to the cfg file.
# Using snapshot-500000 for model C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\dlc-models\iteration-0\Training_projectApr9-trainset95shuffle1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  C:\Users\insan\Desktop\Motion project training\Analysis_video3\Test3_310.mp4
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video3\Test3_310.mp4
# Duration of video [s]:  12.13 , recorded with  60.0 fps!
# Overall # of frames:  728  found with (before cropping) frame dimensions:  1080 1080
# Starting to extract posture
# Cropping based on the x1 = 240 x2 = 600 y1 = 200 y2 = 400. You can adjust the cropping coordinates in the config.yaml file.
# 100%|██████████| 728/728 [00:16<00:00, 44.16it/s]
# Saving results in C:\Users\insan\Desktop\Motion project training\Analysis_video3...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %%
deeplabcut.create_labeled_video(config_path, [video_file3], save_frames = True,displaycropped=True)
# Out:
# Starting to process video: C:\Users\insan\Desktop\Motion project training\Analysis_video3\Test3_310.mp4
# Loading C:\Users\insan\Desktop\Motion project training\Analysis_video3\Test3_310.mp4 and data.
# Duration of video [s]: 12.13, recorded with 60.0 fps!
# Overall # of frames: 728 with cropped frame dimensions: 360 200
# Generating frames and creating video.
# 100%|██████████| 728/728 [01:23<00:00,  8.72it/s]
# Labeled video C:\Users\insan\Desktop\Motion project training\Analysis_video3\Test3_310DLC_resnet50_Training_projectApr9shuffle1_500000_labeled.mp4 successfully created.
# [True]

# %%
deeplabcut.plot_trajectories(config_path,[video_file3], videotype='.mp4')
# Out:
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video3\Test3_310.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
deeplabcut.analyzeskeleton(config_path, [video_file3],videotype='.mp4',save_as_csv=True)
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video3\Test3_310.mp4

# %%
deeplabcut.CropVideo(
    'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video3\\Test3_310.mp4',
    width=350,
    height=350,
    origin_x=400,
    origin_y=200,
    outsuffix='cropped',
    outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
    useGUI=True,
)
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video3\\Test3_310.mp4',
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## video4

# %%
video_file4 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video4\\Test4_309.mp4'

# %%
video4 = deeplabcut.analyze_videos(config_path, [video_file4],videotype='.mp4',auto_track=True,save_as_csv=True,cropping= [250,600,200,450])
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Overwriting cropping parameters: [250, 600, 200, 450]
# These are used for all videos, but won't be save to the cfg file.
# Using snapshot-500000 for model C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\dlc-models\iteration-0\Training_projectApr9-trainset95shuffle1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  C:\Users\insan\Desktop\Motion project training\Analysis_video4\Test4_309.mp4
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video4\Test4_309.mp4
# Duration of video [s]:  10.22 , recorded with  60.0 fps!
# Overall # of frames:  613  found with (before cropping) frame dimensions:  1080 1080
# Starting to extract posture
# Cropping based on the x1 = 250 x2 = 600 y1 = 200 y2 = 450. You can adjust the cropping coordinates in the config.yaml file.
# 100%|██████████| 613/613 [00:09<00:00, 66.00it/s]
# Saving results in C:\Users\insan\Desktop\Motion project training\Analysis_video4...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %%
deeplabcut.create_labeled_video(config_path, [video_file4], save_frames = True,displaycropped=True)
# Out:
# Starting to process video: C:\Users\insan\Desktop\Motion project training\Analysis_video4\Test4_309.mp4
# Loading C:\Users\insan\Desktop\Motion project training\Analysis_video4\Test4_309.mp4 and data.
# Duration of video [s]: 10.22, recorded with 60.0 fps!
# Overall # of frames: 613 with cropped frame dimensions: 350 250
# Generating frames and creating video.
# 100%|██████████| 613/613 [01:06<00:00,  9.25it/s]
# Labeled video C:\Users\insan\Desktop\Motion project training\Analysis_video4\Test4_309DLC_resnet50_Training_projectApr9shuffle1_500000_labeled.mp4 successfully created.
# [True]

# %%
deeplabcut.plot_trajectories(config_path,[video_file4], videotype='.mp4')
# Out:
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video4\Test4_309.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
deeplabcut.analyzeskeleton(config_path, [video_file4],videotype='.mp4',save_as_csv=True)
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video4\Test4_309.mp4

# %%
deeplabcut.CropVideo(
    video_file4,
    width=350,
    height=350,
    origin_x=400,
    origin_y=200,
    outsuffix='cropped',
    outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
    useGUI=True,
)
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     video_file4,
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## video5

# %%
video_file5 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video5\\Test5_308.mp4'

# %%
video5 = deeplabcut.analyze_videos(config_path, [video_file5],videotype='.mp4',auto_track=True,save_as_csv=True,cropping= [210,500,200,450])
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['Pupilup',
#                       'Pupildown',
#                       'Pupilleft',
#                       'Pupilright',
#                       'Eyelidup',
#                       'Eyeliddown',
#                       'Eyelidleft',
#                       'Eyelidright'],
#  'batch_size': 1,
#  'crop_pad': 0,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_Training_projectApr9\\Training_project_TH95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'deterministic': False,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\insan\\anaconda3\\envs\\DEEPLABCUT\\lib\\site-packages\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 1.0,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'mirror': False,
#  'net_type': 'resnet_50',
#  'num_joints': 8,
#  'optimizer': 'sgd',
#  'pairwise_huber_loss': True,
#  'pairwise_predict': False,
#  'partaffinityfield_predict': False,
#  'regularize': False,
#  'scoremap_dir': 'test',
#  'shuffle': True,
#  'snapshot_prefix': 'C:\\Users\\insan\\Desktop\\Motion project '
#                     'training\\Training_nonmulti\\Training_project-TH-2024-04-09\\dlc-models\\iteration-0\\Training_projectApr9-trainset95shuffle1\\test\\snapshot',
#  'stride': 8.0,
#  'weigh_negatives': False,
#  'weigh_only_present_joints': False,
#  'weigh_part_predictions': False,
#  'weight_decay': 0.0001}
# Overwriting cropping parameters: [210, 500, 200, 450]
# These are used for all videos, but won't be save to the cfg file.
# Using snapshot-500000 for model C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\dlc-models\iteration-0\Training_projectApr9-trainset95shuffle1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  C:\Users\insan\Desktop\Motion project training\Analysis_video5\Test5_308.mp4
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video5\Test5_308.mp4
# Duration of video [s]:  11.58 , recorded with  60.0 fps!
# Overall # of frames:  695  found with (before cropping) frame dimensions:  1080 1080
# Starting to extract posture
# Cropping based on the x1 = 210 x2 = 500 y1 = 200 y2 = 450. You can adjust the cropping coordinates in the config.yaml file.
# 100%|██████████| 695/695 [00:09<00:00, 70.90it/s]
# Saving results in C:\Users\insan\Desktop\Motion project training\Analysis_video5...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %%
deeplabcut.create_labeled_video(config_path, [video_file5], save_frames = True,displaycropped=True)
# Out:
# Starting to process video: C:\Users\insan\Desktop\Motion project training\Analysis_video5\Test5_308.mp4
# Loading C:\Users\insan\Desktop\Motion project training\Analysis_video5\Test5_308.mp4 and data.
# Duration of video [s]: 11.58, recorded with 60.0 fps!
# Overall # of frames: 695 with cropped frame dimensions: 290 250
# Generating frames and creating video.
# 100%|██████████| 695/695 [01:16<00:00,  9.03it/s]
# Labeled video C:\Users\insan\Desktop\Motion project training\Analysis_video5\Test5_308DLC_resnet50_Training_projectApr9shuffle1_500000_labeled.mp4 successfully created.
# [True]

# %%
deeplabcut.plot_trajectories(config_path,[video_file5], videotype='.mp4')
# Out:
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video5\Test5_308.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
deeplabcut.analyzeskeleton(config_path, [video_file5],videotype='.mp4',save_as_csv=True)
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video5\Test5_308.mp4

# %%
deeplabcut.CropVideo(
    video_file5,
    width=350,
    height=350,
    origin_x=400,
    origin_y=200,
    outsuffix='cropped',
    outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
    useGUI=True,
)
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     video_file5,
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## video6

# %%
video_file6 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video6\\308_2024-04-26_11-40-26.mp4'

# %%
video6 = deeplabcut.analyze_videos(config_path, [video_file6],videotype='.mp4',auto_track=True,save_as_csv=True,cropping= [250,800,100,390])
# Out:
# Overwriting cropping parameters: [250, 800, 100, 390]
# These are used for all videos, but won't be save to the cfg file.
# Using snapshot-500000 for model C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\dlc-models\iteration-0\Training_projectApr9-trainset95shuffle1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4
# Duration of video [s]:  3231.6 , recorded with  30.0 fps!
# Overall # of frames:  96948  found with (before cropping) frame dimensions:  1280 960
# Starting to extract posture
# Cropping based on the x1 = 250 x2 = 800 y1 = 100 y2 = 390. You can adjust the cropping coordinates in the config.yaml file.
# 100%|██████████| 96948/96948 [25:32<00:00, 63.26it/s]
# Saving results in C:\Users\insan\Desktop\Motion project training\Analysis_video6...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %%
deeplabcut.create_labeled_video(config_path, [video_file6], save_frames = True,displaycropped=True)
# Out:
# Starting to process video: C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4
# Loading C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4 and data.
# Duration of video [s]: 3231.6, recorded with 30.0 fps!
# Overall # of frames: 96948 with cropped frame dimensions: 550 290
# Generating frames and creating video.
# 100%|██████████| 96948/96948 [4:00:05<00:00,  6.73it/s]
# Labeled video C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26DLC_resnet50_Training_projectApr9shuffle1_500000_labeled.mp4 successfully created.
# [True]

# %%
deeplabcut.plot_trajectories(config_path,[video_file6], videotype='.mp4')
# Out:
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
deeplabcut.analyzeskeleton(config_path, [video_file6],videotype='.mp4',save_as_csv=True)
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4

# %%
deeplabcut.filterpredictions(config_path,[video_file6], videotype='.mp4')
# Out:
# Filtering with median model C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4
# Saving filtered csv poses!

# %%
deeplabcut.analyzeskeleton(config_path, [video_file6],videotype='.mp4')
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video6\308_2024-04-26_11-40-26.mp4
# Skeleton in video 308_2024-04-26_11-40-26 already processed. Skipping...

# %%
# deeplabcut.CropVideo(
#     video_file6,
#     width=350,
#     height=350,
#     origin_x=400,
#     origin_y=200,
#     outsuffix='cropped',
#     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#     useGUI=True,
# )
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     video_file6,
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## video7

# %%
video_file7 = 'C:\\Users\\insan\\Desktop\\Motion project training\\Analysis_video7\\309_2024-04-26_15-17-39.mp4'

# %%
video7 = deeplabcut.analyze_videos(config_path, [video_file7],videotype='.mp4',auto_track=True,save_as_csv=True,cropping= [400,800,100,400])
# Out:
# Overwriting cropping parameters: [400, 800, 100, 400]
# These are used for all videos, but won't be save to the cfg file.
# Using snapshot-500000 for model C:\Users\insan\Desktop\Motion project training\Training_nonmulti\Training_project-TH-2024-04-09\dlc-models\iteration-0\Training_projectApr9-trainset95shuffle1
# C:\Users\insan\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  C:\Users\insan\Desktop\Motion project training\Analysis_video7\309_2024-04-26_15-17-39.mp4
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video7\309_2024-04-26_15-17-39.mp4
# Duration of video [s]:  2783.47 , recorded with  30.0 fps!
# Overall # of frames:  83504  found with (before cropping) frame dimensions:  1280 960
# Starting to extract posture
# Cropping based on the x1 = 400 x2 = 800 y1 = 100 y2 = 400. You can adjust the cropping coordinates in the config.yaml file.
# 100%|██████████| 83504/83504 [16:37<00:00, 83.75it/s]
# Saving results in C:\Users\insan\Desktop\Motion project training\Analysis_video7...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %%
deeplabcut.create_labeled_video(config_path, [video_file7], save_frames = True,displaycropped=True)
# Out:
# Starting to process video: C:\Users\insan\Desktop\Motion project training\Analysis_video7\309_2024-04-26_15-17-39.mp4
# Loading C:\Users\insan\Desktop\Motion project training\Analysis_video7\309_2024-04-26_15-17-39.mp4 and data.
# Duration of video [s]: 2783.47, recorded with 30.0 fps!
# Overall # of frames: 83504 with cropped frame dimensions: 400 300
# Generating frames and creating video.
# 100%|██████████| 83504/83504 [3:02:56<00:00,  7.61it/s]
# Labeled video C:\Users\insan\Desktop\Motion project training\Analysis_video7\309_2024-04-26_15-17-39DLC_resnet50_Training_projectApr9shuffle1_500000_labeled.mp4 successfully created.
# [True]

# %%
deeplabcut.plot_trajectories(config_path,[video_file7], videotype='.mp4')
# Out:
# Loading  C:\Users\insan\Desktop\Motion project training\Analysis_video7\309_2024-04-26_15-17-39.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
deeplabcut.analyzeskeleton(config_path, [video_file7],videotype='.mp4',save_as_csv=True)
# Out:
# Processing C:\Users\insan\Desktop\Motion project training\Analysis_video7\309_2024-04-26_15-17-39.mp4

# %%
# deeplabcut.CropVideo(
#     video_file7,
#     width=350,
#     height=350,
#     origin_x=400,
#     origin_y=200,
#     outsuffix='cropped',
#     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#     useGUI=True,
# )
# Out:
# Please, select your coordinates (draw from top left to bottom right ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 deeplabcut.CropVideo(
#       2     video_file7,
#       3     width=350,
#       4     height=350,
#       5     origin_x=400,
#       6     origin_y=200,
#       7     outsuffix='cropped',
#       8     outpath='C:\\Users\insan\\Desktop\\Motion project training\\Training_videos',
#       9     useGUI=True,
#      10 )
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:495, in CropVideo(vname, width, height, origin_x, origin_y, outsuffix, outpath, useGUI)
#     491 if useGUI:
#     492     print(
#     493         "Please, select your coordinates (draw from top left to bottom right ...)"
#     494     )
# --> 495     coords = draw_bbox(vname)
#     497     if not coords:
#     498         return
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\deeplabcut\utils\auxfun_videos.py:611, in draw_bbox(video)
#     605 plt.show(block=False)
#     607 # import platform
#     608 # if platform.system() == "Darwin":  # for OSX use WXAgg
#     609 #    fig.canvas.start_event_loop(timeout=-1)
#     610 # else:
# --> 611 fig.canvas.start_event_loop(timeout=-1)  # just tested on Ubuntu I also need this.
#     612 #    #fig.canvas.stop_event_loop()
#     614 plt.close(fig)
#
# File ~\anaconda3\envs\DEEPLABCUT\lib\site-packages\matplotlib\backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:
